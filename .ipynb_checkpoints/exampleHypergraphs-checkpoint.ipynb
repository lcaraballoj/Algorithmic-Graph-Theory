# %%
import pandas as pd
import matplotlib as mpl
import matplotlib.pyplot as plt
import networkx as nx
import hypernetx as hnx
import pydot
from networkx.drawing.nx_pydot import graphviz_layout

import sys
sys.path.insert(1, 'Algorithms')
from betaAcyclic import checkBetaAcyclic
from grahamsAlgorithm import GYO

# %%
# Draw hypergraph, line graph, dual of the hypergraph, and line graph of the dual
def check(scenes):
    H = hnx.Hypergraph(scenes)

    G=nx.grid_2d_graph(4,4) 
    
    plt.subplot(221)
    drawHypergraph(H)
    
    print('Original Hypergraph: ')
    GYO(scenes)
    checkBetaAcyclic(scenes)
    print('\n')
    plt.subplot(222)
    drawLinegraph(H)
    
    D = H.dual()
    
    plt.subplot(223)
    drawHypergraph(D)
    
    print('\nDual of the Hypergraph: ')
    plt.subplot(224)
    drawLinegraph(D)

# Draw hypergraph
def drawHypergraph(H):
    kwargs = {'layout_kwargs': {'seed': 16}, 'with_node_counts': False, 'with_edge_labels': True}
    
    hnx.drawing.draw(H,
        node_labels_kwargs={
            'fontsize': 12
        },
        edge_labels_kwargs={
            'fontsize': 16
        },
        edges_kwargs={
            'linewidths': 2
        },
        **kwargs
    )

# Draw line graph and check if it is chordal
def drawLinegraph(H):
    G = H.get_linegraph()

    nx.draw(
        G, edge_color='black', width=1, linewidths=1,
        node_size=400, font_size=12, node_color='pink', alpha=1,
        labels={node: node for node in G.nodes()} 
    )
    
    print('The line graph is chordal: ', nx.is_chordal(G))

# %% [markdown]
# # Example from Tractability Beyond...
#
# This is an example from a paper by Matthias Lazinger about nest-set width.
#
# This hypergraph is not $\alpha$-acyclic or $\beta$-acyclic, but has a 2-NEO:
# $$
# O = (\{c,f\}, \{b,e\}, \{a,d\})
# $$

# %%
scenes = {
    'e1': ['a','b','c','d'],
    'e2': ['a','d','e'],
    'e3': ['d','c','f'],
    'e4': ['b','e'],
    'e5': ['c','f']
}

check(scenes)
# Out:
# Original Hypergraph:
# Elimination:
# e1: ['a', 'b', 'c', 'd']
# e2: ['a', 'd', 'e']
# e3: ['d', 'c', 'f']
# e4: ['b', 'e']
# e5: ['c', 'f']
# Reduction:
# e1: ['a', 'b', 'c', 'd']
# e2: ['a', 'd', 'e']
# e3: ['d', 'c', 'f']
# e4: ['b', 'e']
# {'e1': ['a', 'b', 'c', 'd'], 'e2': ['a', 'd', 'e'], 'e3': ['d', 'c', 'f'], 'e4': ['b', 'e'], 'e5': ['c', 'f']}
# {'e1': ['a', 'b', 'c', 'd'], 'e2': ['a', 'd', 'e'], 'e3': ['d', 'c', 'f'], 'e4': ['b', 'e']}
# Elimination:
# e1: ['a', 'b', 'c', 'd']
# e2: ['a', 'd', 'e']
# e3: ['d', 'c']
# e4: ['b', 'e']
# Reduction:
# e1: ['a', 'b', 'c', 'd']
# e2: ['a', 'd', 'e']
# e4: ['b', 'e']
# {'e1': ['a', 'b', 'c', 'd'], 'e2': ['a', 'd', 'e'], 'e3': ['d', 'c'], 'e4': ['b', 'e']}
# {'e1': ['a', 'b', 'c', 'd'], 'e2': ['a', 'd', 'e'], 'e4': ['b', 'e']}
# Elimination:
# e1: ['a', 'b', 'd']
# e2: ['a', 'd', 'e']
# e4: ['b', 'e']
# Reduction:
# e1: ['a', 'b', 'd']
# e2: ['a', 'd', 'e']
# e4: ['b', 'e']
# {'e1': ['a', 'b', 'd'], 'e2': ['a', 'd', 'e'], 'e4': ['b', 'e']}
# {'e1': ['a', 'b', 'd'], 'e2': ['a', 'd', 'e'], 'e4': ['b', 'e']}
# Not alpha acyclic
#
#
#
# HYPERGRAPH:  {'e1': ['a', 'b', 'd'], 'e2': ['a', 'd', 'e'], 'e4': ['b', 'e']}
# Remove vertices that exist in only one hyperedge
#
# FINDING NEST POINTS
# Vertices Edges:  [['a', 'b', 'd'], ['a', 'd', 'e'], ['b', 'e']]
# NODES:  ['a', 'd', 'e', 'b']
# NODE:  a
# Node in:  ['a', 'b', 'd']
# Node in:  ['a', 'd', 'e']
# Edge Dict:  {0: 3, 1: 3}
# Unsrt:  {0: 3, 1: 3}
# Srt: {0: 3, 1: 3}
# Dictionary Keys:  [0, 1]
# EDGE INDEX:  [0, 1]
# Current:  ['a', 'b', 'd']
# Next:  ['a', 'd', 'e']
# NODE:  d
# Node in:  ['a', 'b', 'd']
# Node in:  ['a', 'd', 'e']
# Edge Dict:  {0: 3, 1: 3}
# Unsrt:  {0: 3, 1: 3}
# Srt: {0: 3, 1: 3}
# Dictionary Keys:  [0, 1]
# EDGE INDEX:  [0, 1]
# Current:  ['a', 'b', 'd']
# Next:  ['a', 'd', 'e']
# NODE:  e
# Node in:  ['a', 'd', 'e']
# Node in:  ['b', 'e']
# Edge Dict:  {1: 3, 2: 2}
# Unsrt:  {1: 3, 2: 2}
# Srt: {1: 3, 2: 2}
# Dictionary Keys:  [1, 2]
# EDGE INDEX:  [1, 2]
# Current:  ['a', 'd', 'e']
# Next:  ['b', 'e']
# NODE:  b
# Node in:  ['a', 'b', 'd']
# Node in:  ['b', 'e']
# Edge Dict:  {0: 3, 2: 2}
# Unsrt:  {0: 3, 2: 2}
# Srt: {0: 3, 2: 2}
# Dictionary Keys:  [0, 2]
# EDGE INDEX:  [0, 2]
# Current:  ['a', 'b', 'd']
# Next:  ['b', 'e']
# Nest Points:  []
# Remove empty edges
# ORG:  {'e1': ['a', 'b', 'd'], 'e2': ['a', 'd', 'e'], 'e4': ['b', 'e']}
# NEW:  {'e1': ['a', 'b', 'd'], 'e2': ['a', 'd', 'e'], 'e4': ['b', 'e']}
# Not Beta Acyclic
#
#
# The line graph is chordal:  True
#
# Dual of the Hypergraph:
# The line graph is chordal:  True

# %% [markdown]
# # $\alpha$-acyclic Examples
#
# ## Example 1
#
# From *Hypergraph Theory: An Introduction* (pg 73, Fig 4.6). This graph is $\alpha$-acyclic, $\beta$-acyclic, so it has a 1-NEO.

# %%
scenes = {
    'e1': ['a', 'b', 'c', 'd'],
    'e2': ['b', 'd', 'e', 'f', 'g'],
    'e3': ['d', 'g', 'i', 'j', 'k'],
    'e4': ['b', 'd', 'g']
}

check(scenes)
# Out:
# Original Hypergraph:
# Elimination:
# e1: ['b', 'd']
# e2: ['b', 'd', 'g']
# e3: ['d', 'g']
# e4: ['b', 'd', 'g']
# Reduction:
# {'e1': ['b', 'd'], 'e2': ['b', 'd', 'g'], 'e3': ['d', 'g'], 'e4': ['b', 'd', 'g']}
# {}
# Elimination:
# Reduction:
# {}
# {}
# Alpha Acyclic
#
#
#
# HYPERGRAPH:  {}
# Remove vertices that exist in only one hyperedge
#
# FINDING NEST POINTS
# Vertices Edges:  []
# NODES:  []
# Nest Points:  []
# Remove empty edges
# ORG:  {}
# NEW:  {}
# Beta Acyclic
#
#
# The line graph is chordal:  True
#
# Dual of the Hypergraph:
# The line graph is chordal:  True

# %% [markdown]
# ## Example 2
#
# From *Hypergraph Theory: An Introduction* (pg 74, Fig. 4.8). This graph is $\alpha$-acyclic, NOT $\beta$-acyclic, but has a 2-NEO:
# $$
# O = (\{a,b\}, \{m,n\}, \{k,i\}, \{f,l\}, \{g,h\}, \{c,e\}, \{d.j\})
# $$

# %%
scenes = {
    'e1': ['a', 'b', 'c', 'd', 'e', 'f'],
    'e2': ['d', 'g', 'h'],
    'e3': ['h', 'l', 'm', 'n'],
    'e4': ['f', 'j', 'l'],
    'e5': ['d', 'e', 'f', 'g', 'h', 'i', 'j', 'k', 'l']
}

check(scenes)
# Out:
# Original Hypergraph:
# The line graph is chordal:  False
#
# Dual of the Hypergraph:
# The line graph is chordal:  True

# %% [markdown]
# ## Example 3
#
# From *The complexity of Boolean Conjuctive Queries with Intersection Joins* (pg 61, Fig 4). This graph is $\alpha$-acyclic, has no Berge-cycle, and is $\beta$-acyclic, so it has a 1-NEO.

# %%
scenes = {
    'e1': ['a', 'b'],
    'e2': ['a', 'c'],
    'e3': ['c', 'd'],
    'e4': ['c', 'e']
}

check(scenes)
# Out:
# Original Hypergraph:
# The line graph is chordal:  True
#
# Dual of the Hypergraph:
# The line graph is chordal:  True

# %% [markdown]
# ## Example 4
#
# This graph is $\alpha$-acyclic and not $\beta$-acyclic. It does have a 2-NEO
# $$
# O = (\{b, d\}, \{a, c\})
# $$

# %%
scenes = {
    'e1': ['a', 'b'],
    'e2': ['a', 'c'],
    'e3': ['a', 'b', 'c'],
    'e4': ['a', 'b', 'd']
}

check(scenes)
# Out:
# Original Hypergraph:
# The line graph is chordal:  True
#
# Dual of the Hypergraph:
# The line graph is chordal:  True
# /Users/linneacaraballo/Library/Python/3.9/lib/python/site-packages/networkx/drawing/nx_pylab.py:304: DeprecationWarning: `alltrue` is deprecated as of NumPy 1.25.0, and will be removed in NumPy 2.0. Please use `all` instead.
#   draw_networkx_edges(G, pos, arrows=arrows, **edge_kwds)

# %% [markdown]
# ## Example 5

# %% [markdown]
# # Cycle
# ## Example 1
#
# Not $\alpah$-acyclic or $\beta$-acyclic. No $k$-NEO.

# %%
scenes = {
    'e1': ['a', 'b'],
    'e2': ['b', 'c', 'd'],
    'e3': ['c', 'e', 'f'],
    'e4': ['f', 'i', 'j'],
    'e5': ['h', 'i'],
    'e6': ['a', 'g', 'h']
}

check(scenes)
# Out:
# Original Hypergraph:
# The line graph is chordal:  False
#
# Dual of the Hypergraph:
# The line graph is chordal:  False

# %% [markdown]
# # Normal Hypergraph
#
# From *Hypergraph Theory: An Introduction* (pg 69, Fig. 4.4). This graph is $\alpha$-acyclic, NOT $\beta$-acyclic, no $k$-NEO

# %%
scenes = {
    'e1': ['a', 'b', 'c', 'd', 'e', 'f'],
    'e2': ['d', 'e', 'g', 'h', 'j', 'k'],
    'e3': ['j', 'k', 'l', 'm', 'n'],
    'e4': ['e', 'f', 'h', 'i']
}

check(scenes)
# Out:
# Original Hypergraph:
# The line graph is chordal:  True
#
# Dual of the Hypergraph:
# The line graph is chordal:  True

# %% [markdown]
# # Beta Triangle
#
# $\alpha$-acyclic but not $\beta$-acyclic, no $k$-NEO

# %%
scenes = {
    'e1': ['x', 'y', 'z'],
    'e2': ['x', 'y'],
    'e3': ['y', 'z'],
    'e4': ['x', 'z']
}

check(scenes)
# Out:
# Original Hypergraph:
# The line graph is chordal:  True
#
# Dual of the Hypergraph:
# The line graph is chordal:  True

# %% [markdown]
# # Tetrahedron
#
# Not $\alpha$-acyclic, not $\beta$-acyclic, no $k$-NEO

# %%
scenes = {
    'e1': ['x', 'y', 'z'],
    'e2': ['x', 't', 'z'],
    'e3': ['x', 'y', 't'],
    'e4': ['y', 't', 'z']
}

check(scenes)
# Out:
# Original Hypergraph:
# The line graph is chordal:  True
#
# Dual of the Hypergraph:
# The line graph is chordal:  True

# %% [markdown]
# # Square
#
# Not $\alpha$-acyclic, not $\beta$-acyclic, no $k$-NEO

# %%
scenes = {
    'e1': ['x', 'y'],
    'e2': ['y', 'z'],
    'e3': ['t', 'z'],
    'e4': ['x', 't']
}

check(scenes)
# Out:
# Original Hypergraph:
# The line graph is chordal:  False
#
# Dual of the Hypergraph:
# The line graph is chordal:  False
